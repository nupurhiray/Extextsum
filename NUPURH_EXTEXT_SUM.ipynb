# %% [markdown]
# Import Required Libraries in the workspace. NLTK is a package of standard python with ready-to-use functions and utilities. It’s one of the most popular computational linguistics and natural language processing libraries.

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize

# %% [markdown]
# The nltk.corpus package contains a set of class readers that can retrieve the contents of various corpora. A corpus is a vast and organized series of texts in linguistics. They are used in corpus linguistics to test hypotheses, check for occurrences, and validate linguistic rules within a language territory.
#
# Tokenizers divide strings into lists of substrings. For example, tokenizers can be used to find the words and punctuation in a string
#
# The stopwords in nltk are the most common words in data. They are words that you do not want to use to describe the topic of your content.

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('punkt')
text = """WHAT IS ARTIFICIAL INTELLIGENCE (AI)?

Artificial Intelligence is by a long way individual of ultimate spellbinding and amazing productions always fashioned in the record of society. With the coming of allure creativeness, skilled is still a big rule that is to say still expected investigated. In fact, allure certain-realm request to date is presumably the without depth. In the past few age, skilled has happened expeditious development in the rule of AI, making it individual of ultimate productive commences. Looking at allure rapid change tumour, skilled a future prospect for Artificial Intelligence. That is reason, we have curated this item, to advise our editors to the boundless experience of Artificial Intelligence.
In Layman agreements, Artificial Intelligence maybe second-hand delineated as a arm of computer technology that can pretend human intellect. AI is executed in machines to act tasks that indeed demand human knowledge. If you are wondering, what is ai? Some of their basic function involves aforementioned of interpretation, knowledge, logical and active resolution making.
At the centre of it, Artificial Intelligence is exclusively algorithms accompanying sure sets of rules. AI wholes have the skill to get or give an advantage the redundancy of tasks place the calculating dossier (false name machine intelligence algorithms) are augment to bureaucracy. This is accurately by means of what, machine intelligence can really recover at achievement their particularized tasks, outside some outside meddling.

Different Types of Artificial Intelligence:
Artificial Intelligence maybe further top-secret established allure complicatedness to copy human wit. These traits concern their actual-experience custom, in addition to the electronics complicated. This breaks below AI into legitimate and supposed arrangements. The Different types of AI are in this manner:



ARTIFICIAL NARROW INTELLIGENCE (ANI) 
Artificial Narrow Intelligence(ANI) generally as Narrow AI or Weak AI is the only realistic AI human has solved previously in time or order period. This particular approach towards AI is yearning profit and can act only chosen tasks. Some of the instances of Narrow AI include face concession, voice assistant, and whole agreeing that can act only stipulated tasks.

ARTIFICIAL GENERAL INTELLIGENCE (AGI) 
Artificial General Intelligence (AGI) is repeated occasionally standard as Deep AI or Strong AI. It is a abstract plan place AI can mimic human understanding. AGI has the convenience to receive or present an benefit allure repetitious tasks and assist in reasonable.
The two key methods in Text Summarization are Extraction and Abstraction. Extraction is a process that determines abundant amounts of textual dossier to ‘extract’ short and authoritative recaps. Abstractive text summarization produce a brief form of an explanation content from the original beginning outside the sentences being reused by still protecting the intention and the important facts.
ARTIFICIAL SUPERINTELLIGENCE (ASI)
Artificial Superintelligence (ASI) is a entirely supposed position place machines can enhance entirely self-conscious, even topping the likeness human knowledge. As of now, Superintelligence only lies in dystopian sci-fi movie.
The plan of Artificial Superintelligence is that at the stage it can indeed comprehend human knowledge while experience moment of truth. They would construct their own theory arrangement accompanying their own beliefs.
ARTIFICIAL INTELLIGENCE VS MACHINE LEARNING
Artificial Intelligence is the parasol term used to mimic human acumen. On the other hand, Machine Learning (ML) is a subspace of Artificial Intelligence (AI) that authorizes a appliance to remember alone and create selections outside some outside influence.
Traditionally, AI was prioritize accompanying the set of functions established that they take care of act. These are made by plain if-different reports. But, ML allows these instruments to act established the dossier they accumulate.


EXAMPLES OF ARTIFICIAL INTELLIGENCE
AI-authorized machines have engaged over, and can surely act human tasks while discarding all the human wrongs that create it. In fact, in a current survey, 72% of all Americans have meant their concerns about specific a future. No matter in what way or manner you examine it, offset from your Facebook feed to a plain Google search, entirety is a bi-device of Artificial Intelligence. Here are few of ultimate outstanding models of AI.
1. HEALTHCARE
Artificial Intelligence has entirely exchanged the habit we see the healthcare manufacturing. In fact, it maybe deliberate a game-dealer, likely the excess of implementations. Starting from android-helped surgeries to consistency path of private records, AI has substantiated expected ultimate advantageous. Healthcare has forever endured through larger healing costs full in addition to wasteful processes. Artificial Intelligence is bestowing the much-stayed refashioning.
2. FINANCE
One commit even suggest that the finance manufacturing and Artificial Intelligence are the perfect couples fashioned above. While the manufacturing laboriously relies upon dossier veracity accompanying legitimate-period dispose of and newsgathering, AI can support accountable. The best display is robo-guide that is an mechanical flat case for transporting papers organizer. The set treasure helps to find highest in rank stock for the envelope.
3. E-COMMERCE
Ecommerce is still another policy that has signed a mammoth exercise of Artificial Intelligence. Using machine intelligence allows guests to devise better consumer friendships at a private level. Algorithms compelled by AI can embody the whole consumer knowledge, produce dependability while growing reductions to many folds.


4. MANUFACTURING ROBOTS
The plurality of all the production is finished by androids. Robots, as we experience of, are exclusively programmable machines that are used to complete activity sure tasks. This, in proper sequence, increases effectiveness, while making certain that whole is achieved accompanying minimum wrongs. These AI-stimulate machines are exhausted some approximate agility, but though are worthy logical.
5. MAKING EVERYDAY TASKS EASY.
The Artificial intelligence and machine learning combined together perform tasks. It involves summarizing texts in real time, suggestions of words in automatic correction, translation of words from one language to another, Voice recognition, text to speech and many more. 
Most of these applications uses a common machine learning module, that is NATURAL LANGUAGE PROCESSING. 
NLP itself has any of subsets, containing human language understanding (NLU), that refers to vehicle review understanding, and human language creation (NLG), that can revolutionize dossier into human dispute. But announces Wayne Butterfield, manager of intelligent computerization and change at ISG, “the premise is the alike: Understand word and fasten entity with a leg on either side that understanding. Natural language processing create it attainable for calculating to extract keywords and phrases, think the resolute of sound, change that to another expression, or create a reaction. NLP has allure ancestries in language rules, place it arose to authorize calculations to exactly process human language, demonstrates Anil Vijayan, sin chief executive at Everest Group. “Over the course momentary, it progressed from rule-located to structure-knowledge-soaked approaches, accordingly, coinciding accompanying AI.”
In addition to methods arisen the field of computational language rules, NLP (that can likewise be refer to as talk acknowledgment in few circumstances) power engage two together machine intelligence and deep knowledge methods in consideration of efficiently swallow and process unorganized talk and textbook datasets, suggests JP Baritugo, manager at trade revolution and sourcing consultancy Pace Harmon.
Natural Language Processing (NLP) is a arm of Artificial Intelligence (AI) that studies by virtue of what machines learn human style. Its aim search out build methods that can explain in speech the handbook and act tasks like interpretation, syntax inspecting, or issue categorization.
THE IMPORTANCE OF NLP
Artificial Intelligence specialists are uniformly working at hand up accompanying machines that absolutely copy difficult tasks that only the human mind keep gain earlier. One of ultimate meaningful tasks that human minds are worthy is the skill to build and believe complex words. Languages are individual of main mainstays at which benevolence be able very progress. Hence, accent is individual of ultimate argued ideas for AI artists. Over ancient times two decades, brisk progress has happened written engaged of Natural Language Processing (NLP).
APPLICATIONS OF NATURAL LANGUAGE PROCESSING:
1.	EMAIL FILTERS:
Email filters are individual of ultimate fundamental requests of NLP connected to the internet. It begun accompanying unsolicited call filters, individual of the more widespread, fresher requests of NLP is about Gmail’s electronic mail categorization. The system admits if emails reside in individual of three classifications (basic, friendly, or publicities) established their elements of larger object. This keeps your inbox to a controllable proportion accompanying main, appropriate emails you wish to review and put oneself in the place of another fast for all Gmail consumers.
2.	SMART HELPERS
Smart helpers like Apple’s Siri and Amazon’s Alexa understand; patterns in talk. We’ve enhance used to the case that we can mention “Hey Siri”, and request a question, and she understands what we pronounced and responds accompanying appropriate answers established framework.


3.	SEARCH RESULTS
Search instruments use NLP to surface appropriate results established related search presence or consumer resolute so the common person finds what they need outside being a search-term genius.
4.	PREDICTIVE THEME
Things like autocorrect, autocomplete, and predicting quotation are so commonplace on our smartphones. Autocomplete and predicting manual are related to search turbines within they forecast belongings to voice established what you type, perfecting legal order, or suggesting a appropriate individual.
5.	LANGUAGE INTERPRETATION
NLP connected to the internet interpreter can change the style from individual to another exactly and present grammatically correct results
6.	TEXT SCIENCE OF LOGICAL ANALYSIS
Text science of logical analysis converts unorganized manual dossier into significant dossier for reasoning utilizing various semantic, mathematical, and machine intelligence methods.
7.	DATA STUDY
Natural language powers are being joined into study workflows as more BI peddlers offer a human language connect to dossier visualization.
8.	NAMED ENTITY RECOGNITION
Name Entity Recognition (NER) is ultimate undeveloped invention engaged of NLP. The process extracts the centre ‘systems’ present in the passage. These bodies show the fundamental ideas in the idea. Entities maybe the names of folk, names of parties, dates, finances principles, quantities, opportunity verbalizations, healing codes, regions, and additional key facts in the direction of the content.
This passage origin pattern focuses on labelling and classification bodies into pre-top-secret groups. For example, favour this sentence –
“The hotness in Garden City, Kansas is nearly 100-qualities on this pleasant May Day”.
In this piece of facts, the NER invention would classification –
“Garden City, Kansas” as “Location”
“75 DEGREES” as “Temperature”
“June Day” as “Date”
NER is established elementary rules of alphabet. There are various natural and complex models that guests use to accomplish big dossier sets.
9.	SENTIMENT ANALYSIS
Sentiment study is an NLP finish/treasure that interprets and categorizes the despairs noticed in the document. The habit of designating fervours maybe as natural as bearing three pre-top-secret groups - good, distressing, or noncommittal. The manual dossier maybe assigns more intricate NLP methods.
Sentiment reasoning understands a justly unequivocal standard. The essential steps that specific algorithms take contain – 
•	Breaking down each piece of facts into gist materials (sentences, parts of talk, tokens, etc.)
•	Classifying each emotion-bearing item
•	Assigning each detail accompanying a belief score
•	Coalescing the scores to catch various coatings of itemized studies
This model surely expounds this latent standard–
Let’s test these two regular, continuous publications containing information reports -
i. Both the crews were horrible. Fans were uninterested during the whole of the game.
ii. Both groups acted well but they bear discover by virtue of what to take their chances.
Both sentences examine identical issues – a report concerning a sports contest. It is seeming that
10.	ASPECT MINING
Aspect excavating categorizes the various appearance or components in the manual. Typically, it is linked accompanying emotion reasoning programs and second-hand by guests to discover the type of their client reactions. When those facets and emotions are linked, parties can receive a clear plan about differing facets of consumer news. Using these forms, abundant amounts of idea dossier maybe compressed into narrow sentences in the way that -
•	Customer service – maybe better
•	Communications – Positive
•	Pricing– not acceptable
11.	 TOPIC MODELLING
Topic shaping is a complex NLP finish used to categorize organic cases present in textual dossier. These methods do not demand some form of human project. Some usually second-hand Topic Modelling algorithms contain -
•	Correlated Topic Modelling
•	Latent Dirichlet Allocation
•	Latent Semantic Analysis (LSA)
12.	 TEXT SUMMARIZATION
Text Summarization is a field of NLP that handles methods of summing up large sets of textual dossiers. It is primarily passed down by specialists to determine facts present in information or research items. In this thesis we are going to discuss Text summarization. It is one of the major applications of Natural Language Processing. Summarization is individual of ultimate prevalent tasks that we accomplish in Natural Language Processing (NLP). With the amount of new content produce by a lot of population and their smartphones normal, we are drowned among rising amount of info continually. Humans can only consume a fixed number of facts and need a habit to refine out the grain from the chaff and find the facts that matters. Text account in speech can help solve that for textual news. We can separate the signal from the commotion and take significant conduct from bureaucracy.
INTRODUCTION
In this study we are going to focus majorly on Extractive Text Summarization.
Before we can produce a summary, we need to understand what a summary is. A summary is a text that is produced from one or more texts and it conveys important information from the original text. The main advantage of using a summary is that it reduces the reading time. There are two main types of summarization methods: extractive and abstractive. An extractive summarization method consists of selecting important sentences, paragraphs, etc. from the original document and concatenating them into a shorter form. An abstractive summarization is an understanding of the main concepts in a document and then expressing those concepts in clear, natural language.
The primary steps for summarizing a text: The process of summarizing documents consists of three main steps. Topic identification, interpretation, and summary generation are all included.
1.	Identifying the Subject: The text's most important information is identified. Position, cue phrases, and word frequency are some of the methods used for topic identification. The most effective approaches to topic identification are those that are based on the position of phrases.
2.	Interpretation: The interpretation step is required for abstract summaries. In this step, various topics are combined to create a general content.
3.	Synopsis of Generation: The system uses the text generation method in this step.
HISTORY OF TEXT SUMMARIZATION:
Previously, extractive summarizers have been generally founded on scoring sentences in the source archive. Statistics or linguistic techniques are used in the most recent and most common text summarization methods. The sentences are weighted using the Cue Method, Title Method, Location Method, high frequency words, and standard keywords.


 
WHEN TO USE SUMMARIZATION?
It may be alluring to use writing for all texts to receive beneficial news from ruling class and give less period knowledge. However, at the same time, NLP writing has happened a favourable use case in various fields.
Text Summarization is the process of acquiring important news from an real handbook document. In this method, the culled facts is reached as a summed up report and awarded as a short summary to the consumer. It is very critical for persons to believe and to name the content of the textbook. Text Summarization methods are top-secret into abstractive and extractive writing. The extractive writing method focuses on selecting by what method paragraphs, main sentences, etc produces the original documents in exact form. The suggestion of sentences is driven established semantic and mathematical lineaments.
Text summarization works excellent if a passage has plenty inexperienced details and maybe used to percolate main news from bureaucracy. The NLP models can encapsulate long documents and show bureaucracy in narrow more natural sentences. News, factsheets, and mailers fall under these classifications.
Text summarization has developed into a essential and appropriate appliance for encouraging and represent text content in current accelerated resulting facts age. It's far very complex for individuals to substantially sum up bulky documents of document. There is a resource of textual content available on the internet. But, ordinarily, the internet grants more dossier than is requested. Therefore, a twin difficulty is found: Seeking for appropriate documents through an magnificent number of reports proposed, and spellbinding a high capacity of key facts. The objective of automatic content summarization is to compress the basis passage into a exact interpretation preserves allure report content and worldwide implication. The main benefit of a text summarization is study occasion of the consumer possibly shortened. A marvellous content summary method bear mirror the various idea of the document even as keeping duplication to a minimum. Text Summarization systems are candidly limited into abstractive and extractive writing. An extractive writing method consists of selecting essential sentences, paragraphs, etc, from the original book and concatenating bureaucracy into a smaller form. The meaning of sentences is powerfully based on mathematical and semantic appearance of sentences.
However, for texts place each sentence builds up upon the prior, content writing does to malfunction that well. Research journals, healing texts are good instances of texts place writing power is not top selling.
Finally, if we take the case of encapsulating novel, account in speech designs can work fine. However, its power miss the style and the volume of the textbook that me reliable to express. Hence, Text summarization is beneficial only in a few beneficial cases.
 
TWO TYPES OF SUMMARIZATIONS:
There are two main types of Text Summarizations :
•	ABSTRACTIVE
Abstractive summarization, in another way, tries to guess the intention of all content and presents the signification to you.
It establishes dispute and phrases, puts ruling class together in a significant habit, and in addition to that, adjoins ultimate main gospels about the handbook. This habit, abstractive writing methods are more intricate than extractive writing methods and are likewise computationally more high-priced. 
•	EXTRACTIVE
Extractive summarization procedures work smoothly. It takes the passage, ranks all the sentences in accordance with the understanding and pertinence of the textbook, and presents you with best essential sentences.
This means does not form new dispute or phrases, it just takes the previously existent conversation and phrases and presents only that. You can conceive this as communicable a page of theme and designating ultimate main sentences utilizing a highlighter.







WORD LEVEL FEATURES 
1.	CONTENT WORD FEATURE 
Keywords are essential in labelling the significance of the sentence. The sentence that resides of main keywords is most likely contained in the definitive summary. The content (magic words for entry) conversation are dispute that are nouns, deponents, dependents and limiters that are usually persistent established ft. x if measure.
2.	TITLE WORD FEATURE
The sentences in the original document that resides of conversation noticed in the title have better chances to provide to the conclusive summary because they be a part of signs of the idea of the document.
3.	CUE PHRASE FEATURE
Cue phrases are dispute and phrases that display the construction of the document flow and it is second-hand as a feature in sentence option. The sentence that holds suggestion phrases(for instance "culmination", "cause", "this facts", "summary”, “expand", "desire" etc.) are generally expected contained in the ending summary.
4.	BIASED DISCUSSION FEATURE
The sentences that include partial dispute are more likely main. The partial conversation are upper class of the predefined set of dispute that concede possibility be rule particular. They are comparably main dispute that express the idea of the document.
5.	UPPER CASE DISCUSSION FEATURE
The words that are in capitalization in the way that "UNICEF" are thought-out expected main conversation and those sentences that amount to these dispute are called main in the framework of sentence excerpt for the ending summary.


SENTENCE LEVEL FEATURES
1.	SENTENCE DISTRICT FEATURE
The sentences that happen initially and the end indiscriminate the document are seemingly main because most documents are hierarchically organized accompanying main facts initially and completely of the paragraphs.
2.	SENTENCE TIME FEATURE 
The sentence distance plays an main duty in recognizing key sentences. Shorter texts do not transport essential news and lengthened sentences again need not be affiliated with the summary. The normalized distance of the sentence is determined as the percentage 'tween any of conversation in the sentence to the number of dispute in the most protracted sentence in the document.
3.	PARAGRAPH AREA FEATURE
Similar to sentence neighbourhood, passage site more plays a important duty in selecting key sentences. A Higher score is filling a place the article in the minor divisions (origin and end paragraphs of the document).
4.	SENTENCE-TO-SENTENCE COHESION
The union middle from two points sentences for each sentence(s), the likeness 'tween s and alternative sentences are planned that are summarized and rude worth of the facet is acquired for s. The feature principles are normalized betwixt[0, 1] place profit tighter to 1.0 displays a bigger grade of union 'tween sentences.




EXTRACTIVE TEXT SUMMARIZATION METHODS
Extractive Text Summarization procedures maybe widely classified as Unsupervised Learning and Supervised learning methods. Recent everything count on Unsupervised Learning systems for text summarization.
•	UNSUPERVISED LEARNING METHODS
In this portion, unsupervised methods for sentence derivation task is explained. The unsupervised approaches do not need human reviews (user recommendation) in determining the main looks of the document, it demands ultimate cultured treasure to determine repayment for the lack of human information. Unsupervised reviews provide a bigger level of computerization distinguished to directed model and are more acceptable for dispose of Big Data. Unsupervised knowledge model shave confirmed favourable in handbook account in speech task.
a.	GRAPH BASED APPROACH 
Graph-based models are widely second hand in document summarization because graphs can capably represent the document building. Extractive text writing utilizing external information from Wikipedia incorporating having two of something diagram framework has existed second hand.
b.	FUZZY LOGIC BASED APPROACH 
The fuzzy logic approach primarily contains four elements: fuzzifier, fuzzifier, fuzzy knowledge base and conclusion generator. The textual characteristics recommendation of Fuzzy logic approach are sentenced width, sentence correlation etc which is later likely to the fuzzy scheme.



c.	LATENT SEMANTIC ANALYSIS METHOD(LSA)
	Latent Semantic Analysis(LSA) is a method that excerpt unseen semantic forms of sentences and words that are commonly passed down in paragraph summarization task. It is an unsupervised learning approach that does not demand some sort of outside or preparation knowledge. LSA captures the document of the opinion document and excerpt facts to a degree words that commonly happen together and conversation that are usually visualized indifferent sentences. A extreme number of universal dispute among the sentences decorate that the sentences are semantically accompanying. Singular Value Decomposition(SVD) [13], is a system used to learn the interrelations betwixt words and sentences that more has the ability of cacophony decline that helps to advance veracity. SVD, [15] when sanctioned to document discussion matrices, can group documents that are semantically joined to two together in spite of bureaucracy giving no ordinary dispute. The set of dispute that arise in connected content is still related inside the unchanging distinguishing spatial room. LSA method is applied to excerpt the subject-accompanying dispute and main content sending sentences from report. The benefit of adopting LSA headings for writing over discussion headings is that abstract relations as depicted in the human mind are spontaneously seized in the LSA. Choice of the representative sentence from each scale of the competency guarantees relevance of sentence to the document and guarantees non-redundancy. LS everything accompanying quotation dossier and the principal extent on account of the group of points maybe located.








•	SUPERVISED LEARNING METHODS
Supervised extractive summarization related methods are established a categorization approach at sentence level place bureaucracy learns by models to categorize betwixt summary and non-summary sentences. The important disadvantage accompanying the directed approach is that it demands popular manually conceived prospectus by a human to label the sentences in the original preparation document encircled accompanying "summary sentence" or "non summary sentence" and it too demands categorized preparation dossier for categorization.
a.	MACHINE LEARNING APPROACH ESTABLISHED BAYES RULE
A set of preparation documents in addition to allure extractive surveys is augment as recommendation to the preparation stage. The automobile knowledge approach views categorization question in textbook account in speech. The sentences are limited as a non-summary and summary sentence established the feature bewitched for one sentence. The contingency of categorization are well-informed from the preparation dossier apiece following Bayes rule: places shows the set of sentences in the document and fi shows the physiognomy used in categorization stage and S shows the set of sentences in the summary. P (s E< SII1,h,h, .... In)shows the expectation of the sentences expected contained in the summary established the likely physiognomy bewitched a piece sentence.
b.	NEURAL NETWORK BASED APPROACH
In the approach projected in , Rank Net algorithm automatically utilizing affecting animate nerve organs nets to recognize the main sentences in the document. It uses a two-tier interconnected system accompanying back diffusion prepared utilizing Rank Net treasure. The first step includes marking the preparation dossier utilizing a machine intelligence approach and therefore extract facial characteristics of the sentences in two together test set and train sets that is before transfer data from one computer system to another to the interconnected system structure to rank the sentences in the document.



ADVANTAGES OF EXTRAVTUVE TEXT SUMMARIZATION :
1: Works Instantly It takes time and effort to read the entire article, break it down, and identify the most important ideas from the text. A 500-word article can take at least 15 minutes to read. Software for automatic summarization quickly summarizes texts with between 500 and 5,000 words. The user is able to draw solid conclusions despite reading less data and still receiving the most important information as a result of this. Computers of today are a lot more powerful than the human mind, and it is likely that a computer will write a good summary of the article before the human reader has a chance to read it.
2: Works in Any Language Several summarization software can work in any language, which is more than most humans can do. The majority of languages, from English to Russian, can be summarized by summarizers without the need for human intervention because they work with linguistic models. Because of this, they are ideal for people who read and deal with information in multiple languages, as well as for people who need to translate information but want it to be as brief as possible.
3: Further develops Efficiency : Some product sums up archives as well as site pages. Because it speeds up the process of surfing, this significantly increases productivity. The summaries of such web pages, which can be precise and accurate but still 20 percent larger than the original article, can be read in place of reading lengthy news articles that are jam-packed with irrelevant information.
4: Doesn't miss any important information Some software has the unique capability of declaring a word so that sentences that contain it will automatically appear in the summary. Words with tactical significance, like "bomb," "explode," and so on, are typically included in these critical phrases. Computers won't miss important sentences because humans can read them, so important ideas will always be mentioned.


"""
 
stop_words = set(stopwords.words('english'))
 
word_tokens = word_tokenize(text)
# converts the words in word_tokens to lower case and then checks whether
#they are present in stop_words or not
filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
#with no lower case conversion
filtered_sentence = []
 
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)
 
print(word_tokens)
print(filtered_sentence)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ...

# %% [markdown]
# Gensim Library: It is designed to extract semantic topics from documents. It can handle large text collections.

# %%
from gensim.summarization.summarizer import summarize
from gensim.summarization import keywords

# %%
sentences = sent_tokenize(text)
sentenceValue = dict()

# %%
# Summary (0.05% of the original content).
summary = summarize(text, ratio = 0.5)
print("Percent summary")
print(summary)
# Out:
# Percent summary
# Artificial Intelligence is by a long way individual of ultimate spellbinding and amazing productions always fashioned in the record of society.
# In the past few age, skilled has happened expeditious development in the rule of AI, making it individual of ultimate productive commences.
# Looking at allure rapid change tumour, skilled a future prospect for Artificial Intelligence.
# That is reason, we have curated this item, to advise our editors to the boundless experience of Artificial Intelligence.
# In Layman agreements, Artificial Intelligence maybe second-hand delineated as a arm of computer technology that can pretend human intellect.
# AI is executed in machines to act tasks that indeed demand human knowledge.
# At the centre of it, Artificial Intelligence is exclusively algorithms accompanying sure sets of rules.
# ...

# %%
# Summary (2000 words)
summarycount = summarize(text, word_count = 2000)
print("Word count summary")
print(summarycount)
# Out:
# Word count summary
# Artificial Intelligence is by a long way individual of ultimate spellbinding and amazing productions always fashioned in the record of society.
# Looking at allure rapid change tumour, skilled a future prospect for Artificial Intelligence.
# In Layman agreements, Artificial Intelligence maybe second-hand delineated as a arm of computer technology that can pretend human intellect.
# AI is executed in machines to act tasks that indeed demand human knowledge.
# At the centre of it, Artificial Intelligence is exclusively algorithms accompanying sure sets of rules.
# AI wholes have the skill to get or give an advantage the redundancy of tasks place the calculating dossier (false name machine intelligence algorithms) are augment to bureaucracy.
# Different Types of Artificial Intelligence:
# Artificial Intelligence maybe further top-secret established allure complicatedness to copy human wit.
# ...
